# %%
import math
import sys

# %%
#functions for heap data structure
#adjacency lists are implemented as python dictionaries

def PARENT(i,D):
    n = len(D)
    if i>0:
        return math.floor((i-1)/2) 
    else:
        return -1

def LCHILD(i,D):
    n = len(D)
    if ((2*i)+1) < n:
        return (2*i)+1 
    else:
        return -1

def RCHILD(i,D):
    n = len(D)
    if ((2*i)+2) < n:
        return (2*i)+2 
    else:
        return -1

def RSIB(i,D):
    n = len(D)
    if i<(n-1) and i%2 == 1:
        return i+1
    else:
        return -1

def PERC_UP(i,D):
    while i>0 and D[i][1]<D[PARENT(i,D)][1]:
        p = D[i] 
        D[i] = D[PARENT(i,D)]
        D[PARENT(i,D)] = p
        i = PARENT(i,D)
    return D

def INSERT(v,D):
    n = len(D)
    D.insert(n,v)
    PERC_UP(n,D)
    return D

def PERCDOWN(i,D):
    while (RCHILD(i,D)!=-1 and D[i][1]>D[RCHILD(i,D)][1]) or (LCHILD(i,D)!=-1 and D[i][1]>D[LCHILD(i,D)][1]):
        if RCHILD(i,D)==-1:
            j = LCHILD(i,D)
        elif LCHILD(i,D)==-1:
            j = RCHILD(i,D)
        else: 
            j = RCHILD(i,D)
            if D[LCHILD(i,D)][1]<D[RCHILD(i,D)][1]:
                j = LCHILD(i,D)
        
        p = D[i]
        D[i] = D[j]
        D[j] = p
        i = j        
    return D

def DELETEMIN(D):
    n = len(D)-1
    smallest = D[0]
    D[0]=D[n]
    del D[n]
    D = PERCDOWN(0,D)
    return D, smallest

def DECREASE(i,new_value,D):
    D[i] = (D[i][0],new_value)
    D = PERC_UP(i,D)
    return D

# %%
def initialize_D(start_vertex, graph):
    infty = float("inf") #infinity value, change this to 10,000 before submitting the code
    vertices = [key for key in graph]
    start_vertex_ngbrs = graph[start_vertex]
    D = [(start_vertex,0)]
    vertices.remove(start_vertex)    
    #if you want to uncomment the 3 lines below, the back pointer must be initialized 
    #so that vertices adjacent to the starting vertex point to the starting vertex
    #for nghbr in start_vertex_ngbrs: 
    #    D = INSERT((nghbr[0],nghbr[1]),D)
    #    vertices.remove(nghbr[0])    
    for v in vertices:
        D = INSERT((v,infty),D)        
    return D

def index_in_list(vert_indx,D):
    i = 0
    for v in D:
        if v[0] == vert_indx:
            return i
        i+=1
    return -1

def print_paths(graph, start_vertex, back_pointer):
    for key in graph:
        l = []
        k = key
        while k != back_pointer[k]:
            l.append(k)
            k = back_pointer[k]            
        l.append(start_vertex)
        l = l[::-1]
        print('path from {} to {} is given by:'.format(start_vertex,key),l)
        print('total cost of this path is:',find_path_length(l,graph))
    return

def find_path_length(l,graph):
    length = 0
    for i in range(len(l)-1):
        idx = index_in_list(l[i+1],graph[l[i]])        
        length+= graph[l[i]][idx][1]
        
    return length

def run_Dijkstras(start_vertex, graph):
    back_pointer = {key:key for key in graph}
    mark = {key:0 for key in graph} #0 for unmarked, 1 for marked

    D = initialize_D(start_vertex, graph)

    #for strt_nbrs in graph[start_vertex]:
    #    back_pointer[strt_nbrs[0]] = start_vertex

    while 0 in list(mark.values()):
        D, v = DELETEMIN(D)
        current_vertex = v[0]
        mark[current_vertex] = 1
        for adj_vert in graph[current_vertex]:
            adj_indx = adj_vert[0]
            adj_cost = adj_vert[1]
            j = index_in_list(adj_indx,D)
            if mark[adj_indx] == 0 and D[j][1]>v[1]+adj_cost:
                D = DECREASE(j,v[1]+adj_cost,D)
                back_pointer[adj_indx] = current_vertex
    
    return back_pointer

def words_in_name(lst):
    new_list = []
    for piece in lst:
        word = piece.rstrip('&"\/').lstrip('&"\/').split('-')
        if len(word[0]) > 0:
            new_list = new_list+word            
    return new_list


def create_vertex_data():
    vertex_data = read_from_file("MapDataVertices.txt")
    for element in vertex_data:
        element[2] = int(element[2])
        element[3] = int(element[3])
        #element[4] = element[4]#.split()#words_in_name(element[4].split())
    return vertex_data      #returns a list of tuples: 
                            #(vertex_id,label,x-coordinate,y-coordinate,name,list of words in the name)

def read_from_file(filename):
    data = []
    with open(filename) as f:
        for line in f:
            fields = line.split('"')[0].split()
            
            if fields!=[] and fields[0][0]!='/':
                name = line.split('"')[1]
                data.append([int(fields[0])]+fields[1:]+[name])
    return data

def create_edge_data():    
    edge_data = read_from_file("MapDataEdges.txt")
    for element in edge_data:
        element[3] = int(element[3])
        element[4] = int(element[4])
        element[5] = int(element[5])
        element[6] = int(element[6])
        element[8] = element[8].strip('()')
    return edge_data

def construct_graph(vertex_data, edge_data, has_skateboard, minimize_time):
    
    graph = {vertex[0]:[] for vertex in vertex_data}
    for edge in edge_data:
        if minimize_time:
            cost = calculate_time(edge[5],has_skateboard,edge[8])
        else:
            cost = edge[5]
        
        graph[edge[3]].append(
            (edge[4],
             cost,
             edge[0]
            )
        )
    
    return graph

def make_path(graph, start_vertex, end_vertex, back_pointer, edge_data, has_skateboard):
    l = []
    while end_vertex != back_pointer[end_vertex]:
        l.append(end_vertex)
        end_vertex = back_pointer[end_vertex]            
    l.append(start_vertex)
    l = l[::-1]
    return l

def create_output(l, graph, edge_data, has_skateboard):
    time = 0
    distance = 0
    legs = 0
    path_list = []
    
    for i in range(len(l)-1):
        v = l[i]
        j = index_in_list(l[i+1],graph[l[i]])
        edge_indx = graph[l[i]][j][2]
        
        dist_for_leg = edge_data[find_index_in_edge_data(edge_indx,edge_data)][5]
        time_for_leg = calculate_time(dist_for_leg,has_skateboard,edge_data[find_index_in_edge_data(edge_indx,edge_data)][8])
        time += time_for_leg
        distance += dist_for_leg
        legs += 1 
        path_list.append('FROM: ({}) {}\n'.format(vertex_data[l[i]][1],vertex_data[l[i]][-1]))
        path_list.append('ON: {}\n'.format(edge_data[find_index_in_edge_data(edge_indx,edge_data)][-1]))
        path_list.append('Travel {} feet in direction {} degrees {}\n'.format(dist_for_leg,edge_data[find_index_in_edge_data(edge_indx,edge_data)][-4],edge_data[find_index_in_edge_data(edge_indx,edge_data)][-3]))
        path_list.append('TO: ({}) {}\n'.format(vertex_data[l[i+1]][1],vertex_data[l[i+1]][-1]))
        path_list.append('({} seconds)\n\n'.format(time_for_leg))
    path_list.append('legs = {}, distance = {} feet, time = {} seconds\n'.format(legs,distance,time))
    return ''.join(path_list)

def calculate_time(edge_length, has_skateboard, C):

    WalkSpeed = 272    #ft/min = (3.1 miles/hr) * (5280 ft/mile) / (60 mins/hr)
    WalkFactorU = 0.9  #Multiply walk speed by this for walk up.
    WalkFactorD = 1.1  #Multiply walk speed by this for walk down.
    SkateFactorU = 1.1 #Multiply walk speed by this for skateboard up.
    SkateFactorF = 2.0 #Multiply walk speed by this for skateboard flat.
    SkateFactorD = 5.0 #Multiply walk speed by this for skateboard down.
    StepFactorU = 0.5  #Multiply walk speed by this for walk up steps.
    StepFactorD = 0.9  #Multiply walk speed by this for walk down steps.
    BridgeFactor = 1.0 #Multiply walk speed by this for walking on a bridge.

    div_factor = {
        'f': 1,          
        'x': (int(has_skateboard)*SkateFactorF + (int(not has_skateboard))*1),
        'F': int(has_skateboard)*SkateFactorF + (int(not has_skateboard))*1,
        'u': WalkFactorU,
        'U': int(has_skateboard)*SkateFactorU + (int(not has_skateboard))*WalkFactorU,
        'd': WalkFactorD,
        'D': int(has_skateboard)*SkateFactorD + (int(not has_skateboard))*WalkFactorD,
        's': StepFactorU,
        't': StepFactorD,
        'b': BridgeFactor                             
        }
    
    t = int(60*float(edge_length)/float(WalkSpeed) + 0.5) 
    t /= div_factor[C]

    return int(t)

def create_route_file(l, vertex_data):
    MapWidthFeet = 5521 
    MapHeightFeet = 4369 
    MapWidthPixels = 2528 
    MapHeightPixels = 2000 
    CropLeft = 150 
    CropDown = 125 
    file = open(r"Route.txt","w+") 
    file_cropped = open(r"RouteCropped.txt","w+")
    for i in range(len(l)-1):
        v = vertex_data[find_index_in_edge_data(l[i],vertex_data)][2]
        w = vertex_data[find_index_in_edge_data(l[i],vertex_data)][3]
        x = vertex_data[find_index_in_edge_data(l[i+1],vertex_data)][2]
        y = vertex_data[find_index_in_edge_data(l[i+1],vertex_data)][3]
        a = int(v * MapHeightPixels / MapHeightFeet)
        b = int(w * MapWidthPixels / MapWidthFeet)
        c = int(x * MapHeightPixels / MapHeightFeet)
        d = int(y * MapWidthPixels / MapWidthFeet)
        file.write('{} {} {} {}\n'.format(a,b,c,d))
        a = a - CropLeft
        b = b - CropDown
        c = c - CropLeft
        d = d - CropDown
        file_cropped.write('{} {} {} {}\n'.format(a,b,c,d))
    file.close()    
    file_cropped.close()    
    return

def plot_on_map():
    from PIL import Image, ImageDraw
    img = Image.open('BrandeisMapLabeled.jpg')
    drawing = ImageDraw.Draw(img)
    with open('Route.txt') as f:
        for line in f:
            coords = line.split()
            a, b, c, d = int(coords[0]), int(coords[1]), int(coords[2]), int(coords[3])
            drawing.line([(a,b),(c,d)],fill='pink',width=15)        
    img.show()
    return

def print_list(l):
    for i in l:
        print('*',i)
    return 

def get_vertex_id(s, vertex_data): #get vertex id from the input string s
    l = []
    for data in vertex_data:
        if s.lower() == data[1].lower():
            return data[0]
        if s.lower() == data[4].lower():
            return data[0]
        
        if s.lower() in data[4].lower():
            l.append(data[0])
        
    if len(l)==1:
        return l[0]
    if len(l)>1:
        print('Ambigous name. Following multiple matches found.\n')
        print_list([vertex_data[i][4] for i in l])
        print('\nPlease enter a substring that uniquely identifies the place.\n')
        return 0
    if len(l)==0:
        print('Place not found. Try again.')
        return 0

#the string entered should be either the map location, for example L24 etc, or, a substring of a unique name 
#so either the full name or a word that uniquely identifies the location for example 'farber', 'Farber l', 'Farber lib'
#are all substrings of unique location 'Farber Library'

#not case sensitive so more flexible
#    return -1 #location not found, try again
#    return -2 #more than one location for example 'schwartz will give two locations', 'Hassenfeld Lot will give two locations'

#maybe just return a single location error and try again- NO!!! the 
#first check if it matches map location
#then check if it is exactly the name of a place
#then check if it is substring

# %% [markdown]
# # Part 2

# %%
def is_undirected(graph): #checks if every edge - reverse-edge pair has the same weight, 
                          #so that the graph represented by adjacency list can be interpreted as undirected
    result = True
    for key in graph:
        for vert in graph[key]:
            vertex_indx = vert[0]
            edge_wt = vert[1]
            j = index_in_list(key, graph[vertex_indx])
            reverse_edge_wt = graph[vertex_indx][j][1]
            if edge_wt!=reverse_edge_wt:
                print(key,vertex_indx,edge_wt,j,reverse_edge_wt)
                result = False
    return result
def just_one(a, b, l):
    return ((a in l) and (b not in l)) or ((a not in l) and (b in l))

def find_index_in_edge_data(idx,edge_data):
    l = [x[0] for x in edge_data]
    return l.index(idx)

def min_span_tree(graph, start_vertex, edge_data):
    T = set()
    to_put_back = []
    vertices_in_T = set()
    vertices_in_T.add(start_vertex)
    
    edge_cost_pairs = set()
    for key in graph:
        for element in graph[key]:
            edge_cost_pairs.add((element[2],element[1]))
    heap = []
    
    for x in list(edge_cost_pairs):
        heap = INSERT(x,heap)
    
    num_vertices = len(graph)
    while len(T)<num_vertices-1:
        heap, smallest = DELETEMIN(heap)
        smallest = smallest[0]
        indx_sm_edge_data = find_index_in_edge_data(smallest,edge_data)
        
        while not just_one(edge_data[indx_sm_edge_data][3],edge_data[indx_sm_edge_data][4],vertices_in_T): #loop until there is a edge with exactly one 
            to_put_back.append(smallest)
            
            #print(heap)
            #print(len(vertices_in_T))
            heap, smallest = DELETEMIN(heap)
            
            smallest = smallest[0]
            indx_sm_edge_data = find_index_in_edge_data(smallest,edge_data)
        T.add(smallest)
        vertices_in_T.add(edge_data[indx_sm_edge_data][3])
        vertices_in_T.add(edge_data[indx_sm_edge_data][4])
        for edg in to_put_back:
            heap = INSERT((edg,edge_data[find_index_in_edge_data(edg,edge_data)][5]),heap)
        to_put_back = []
        
    return T

def plot_edges(edge_list, edge_data, vertex_data):#needs to be changed!!!!!!!!
    MapWidthFeet = 5521 
    MapHeightFeet = 4369 
    MapWidthPixels = 2528 
    MapHeightPixels = 2000
    img = Image.open('BrandeisMapLabeled.jpg')
    drawing = ImageDraw.Draw(img)
    for edg in edge_list:
        v_1 = edge_data[edg][3]
        v_2 = edge_data[edg][4]
        v = vertex_data[v_1][2]
        w = vertex_data[v_1][3]
        x = vertex_data[v_2][2]
        y = vertex_data[v_2][3]
        a = int(v * MapHeightPixels / MapHeightFeet)
        b = int(w * MapWidthPixels / MapWidthFeet)
        c = int(x * MapHeightPixels / MapHeightFeet)
        d = int(y * MapWidthPixels / MapWidthFeet)
        drawing.line([(a,b),(c,d)],fill='pink',width=10)  
        
    img.show()
    return

def plotting_cordinates_from_edges(edge_list, edge_data, vertex_data):
    MapWidthFeet = 5521 
    MapHeightFeet = 4369 
    MapWidthPixels = 2528 
    MapHeightPixels = 2000
    coords = []
    for edg in edge_list:
        v_1 = edge_data[find_index_in_edge_data(edg,edge_data)][3]
        v_2 = edge_data[find_index_in_edge_data(edg,edge_data)][4]
        v = vertex_data[v_1][2]
        w = vertex_data[v_1][3]
        x = vertex_data[v_2][2]
        y = vertex_data[v_2][3]
        a = int(v * MapHeightPixels / MapHeightFeet)
        b = int(w * MapWidthPixels / MapWidthFeet)
        c = int(x * MapHeightPixels / MapHeightFeet)
        d = int(y * MapWidthPixels / MapWidthFeet)
        coords.append(str(a)+' '+str(b)+' '+str(c)+' '+str(d))
        
    
    return '\n'.join(coords)

def tree_from_edges(edges,  vertex_data, edge_data):
    
    tree = {key[0]: set() for key in vertex_data}
    
    for edge in edges:
        edge_idx = find_index_in_edge_data(edge,edge_data)
        v1 = edge_data[edge_idx][3]
        v2 = edge_data[edge_idx][4]
        tree[v1].add((v2,0))#0 is a dummy coordinate in the tuple
        tree[v2].add((v1,0))#0 is a dummy coordinate in the tuple
        
    for key in tree:
        tree[key] = list(tree[key])
    return tree
        
def plot_traversal(traversal,  vertex_data):#needs to be changed!!!!!!!!
    from PIL import Image, ImageDraw
    MapWidthFeet = 5521 
    MapHeightFeet = 4369 
    MapWidthPixels = 2528 
    MapHeightPixels = 2000
    img = Image.open('BrandeisMapLabeled.jpg')
    drawing = ImageDraw.Draw(img)
    visited = []
    for i in range(len(traversal)-1):
        
        v_1 = traversal[i]
        v_2 = traversal[i+1]
        visited.append(v_1)
        v = vertex_data[v_1][2]
        w = vertex_data[v_1][3]
        x = vertex_data[v_2][2]
        y = vertex_data[v_2][3]
        a = int(v * MapHeightPixels / MapHeightFeet)
        b = int(w * MapWidthPixels / MapWidthFeet)
        c = int(x * MapHeightPixels / MapHeightFeet)
        d = int(y * MapWidthPixels / MapWidthFeet)
        drawing.line([(a,b),(c,d)],fill='pink',width=10)  
        
        if v_2 in visited:
            drawing.line([(a,b),(c,d)],fill='red',width=2)  
        else:
            drawing.line([(a,b),(c,d)],fill='pink',width=10)  
        
    img.show()
    return

def pre_order_trvsl(tree, root_key, vistd_vrtx_list):#returns a list of vertices in the order in which they are traversed
    vistd_vrtx_list.append(root_key)
    for nghbr in tree[root_key]:
        if nghbr[0] not in vistd_vrtx_list:
        
            vistd_vrtx_list = pre_order_trvsl(tree,nghbr[0],vistd_vrtx_list)
            
        if vistd_vrtx_list[-1]!=root_key:
            vistd_vrtx_list.append(root_key)    
    return vistd_vrtx_list

def find_cost(a,b, graph):
    for e in graph[a]:
        if b==e[0]:
            return e[1]
    return float("inf")

#if the next vertex is already visited, look two places ahead and if there's a path to that and the distance through that parth is shorter
#(yes, this needs to be checked as it is not always true) then shortcut it.T
def prim_shortchut_traversal(traversal, graph):
    visited = [traversal[0]]
    i = 0
    while i < len(traversal)-2:
        v_1 = traversal[i]
        v_2 = traversal[i+1]
        v_3 = traversal[i+2]
        
        #if find_cost(v_1,v_3, graph)<float("inf"):#if there is any edge at all shortcut it
        if (find_cost(v_1,v_3, graph)<find_cost(v_1,v_2, graph)+find_cost(v_2,v_3, graph)) and (v_2 in visited):#shortcut only if the new edge is better
            visited.append(v_3)
            i+=2
        else:
            visited.append(v_2)
            i+=1
    return visited

#a dict with keys as vertices and values as an index of set, which is initially all different but set same for unioning 2 sets
def kruskal_min_spanning_tree(edge_data, vertex_data, graph):
    vertex_sets_indices = {key[0]:key[0] for key in vertex_data}#assign all set indices as distinct
    T = set()
    edge_cost_pairs = set()
    for key in graph:
        for element in graph[key]:
            edge_cost_pairs.add((element[2],element[1]))
    heap = []
    for x in list(edge_cost_pairs):
        heap = INSERT(x,heap)
    n_vert = len(vertex_data)
    while len(T)<n_vert-1:
        to_put_back = []
        while True:
            heap, smallest = DELETEMIN(heap)
            smallest = smallest[0]
            indx_sm_edge_data = find_index_in_edge_data(smallest,edge_data)
            v_1 = edge_data[indx_sm_edge_data][3]
            v_2 = edge_data[indx_sm_edge_data][4]
            if vertex_sets_indices[v_1]!=vertex_sets_indices[v_2]:
                T.add(smallest)
                n1 = vertex_sets_indices[v_1]
                n2 = vertex_sets_indices[v_2]
                n = max([n1,n2])
                for key in vertex_sets_indices:
                    if vertex_sets_indices[key]==n1 or vertex_sets_indices[key]==n2:
                        vertex_sets_indices[key]=n
                for edg in to_put_back:
                    heap = INSERT((edg,edge_data[find_index_in_edge_data(edg,edge_data)][5]),heap)
                    
                break
            else:
                
                to_put_back.append(smallest)
    return T

def prim_preorder(start_vertex, vertex_data, edge_data):
    graph_new = construct_graph(vertex_data[5:], edge_data[20:], False, False) #delete the black hole and corners vertices and edges
    min_tree_edges = min_span_tree(graph_new, start_vertex, edge_data[20:])
    prim_min_spanning_tree = tree_from_edges(min_tree_edges, vertex_data[5:], edge_data[20:])    
    traversal = pre_order_trvsl(prim_min_spanning_tree, start_vertex, [])
    output = create_output(traversal,graph_new,edge_data[20:], False)
    print('Would you like to plot the result from Route.txt into the brandeis map? (Requires the python package PIL to be installed)')
    print('y/n - default n? ')
    plot = input()
    print(output)
    create_route_file(traversal,vertex_data)
    
    if plot.lower() == 'y':
        plot_on_map()
    #plot_traversal(traversal, vertex_data)
    
    #plot_traversal(traversal, vertex_data)
    
    
    return output, traversal

def prim_shortcut(start_vertex, vertex_data, edge_data):
    graph_new = construct_graph(vertex_data[5:], edge_data[20:], False, False) #delete the black hole and corners vertices and edges
    min_tree_edges = min_span_tree(graph_new, start_vertex, edge_data[20:])
    prim_min_spanning_tree = tree_from_edges(min_tree_edges, vertex_data[5:], edge_data[20:])
    traversal = pre_order_trvsl(prim_min_spanning_tree, start_vertex, [])    
    prim_shortcut_trav = prim_shortchut_traversal(traversal, graph_new)
    output = create_output(prim_shortcut_trav,graph_new,edge_data[20:], False)
    print('Would you like to plot the traversal onto the brandeis map? (Requires the python package PIL to be installed)')
    print('y/n - default n? ')
    plot = input()
    print(output)
    create_route_file(prim_shortcut_trav,vertex_data)
    
    if plot.lower() == 'y':
        plot_on_map()
    #plot_traversal(traversal, vertex_data)
    
    #plot_traversal(prim_shortcut_trav, vertex_data)
    return output, prim_shortcut_trav

def kruskal_preorder(start_vertex, vertex_data, edge_data):
    graph_new = construct_graph(vertex_data[5:], edge_data[20:], False, False) #delete the black hole and corners vertices and edges
    kruskal_edges = kruskal_min_spanning_tree(edge_data[20:],vertex_data[5:], graph_new)
    k_min_spanning_tree = tree_from_edges(kruskal_edges, vertex_data[5:], edge_data[20:])
    traversal = pre_order_trvsl(k_min_spanning_tree, start_vertex, [])
    output = create_output(traversal,graph_new,edge_data[20:], False)
    print('Would you like to plot the traversal onto the brandeis map? (Requires the python package PIL to be installed)')
    print('y/n - default n? ')
    plot = input()
    print(output)
    create_route_file(traversal,vertex_data)
    
    if plot.lower() == 'y':
        plot_on_map()
    #plot_traversal(traversal, vertex_data)
    return output, traversal

def tour(start_vertex, vertex_data, edge_data):
    print('Enter one of these tour options:')
    print('    0: Preorder traversal of Prim tree')
    print('    1: Triangle shorcuts of Prim traversal')
    print('    2: Preorder traversal of Kruskal tree')
    print('    or return to quit')
    option = input()
    if option == '0':
        prim_preorder(start_vertex, vertex_data, edge_data)
    elif option == '1':
        prim_shortcut(start_vertex, vertex_data, edge_data)
    elif option == '2':        
        kruskal_preorder(start_vertex, vertex_data, edge_data)
    elif option == '':
        sys.exit('You pressed return')
    else:
        print('Enter valid option')
        tour(start_vertex)
    return

# %%
def find_path(start_vertex, end_vertex, vertex_data, edge_data, has_skateboard, minimize_time):
    graph = construct_graph(vertex_data, edge_data, has_skateboard, minimize_time)
    back_pointer = run_Dijkstras(start_vertex,graph)
    l = make_path(graph, start_vertex, end_vertex, back_pointer, edge_data, has_skateboard)
    output = create_output(l, graph, edge_data, has_skateboard)
    
    return l, output


def run_map(vertex_data, edge_data):
    print("******************************WELCOME TO THE BRANDEIS MAP******************************\n")
    print('Entered locations may be: \nthe map location(eg L1, U22 etc) or, \nthe exact name (farber library etc), or, \na substring that uniqiely identifies the place (eg., farber l etc)\n')

    got_location = False
    while got_location == False:
        print('Enter start (return to quit):')
        inp = input()
        if inp == '':
            sys.exit('You pressed return.')
        start_vertex = get_vertex_id(inp,vertex_data)
        if start_vertex!=0:
            got_location = True


    got_location = False
    while got_location == False:
        print('Enter finish (or return to do a tour):')
        inp = input()
        if inp == '':
            tour(start_vertex, vertex_data, edge_data)
            sys.exit()
        end_vertex = get_vertex_id(inp,vertex_data)

        if end_vertex!=0:
            got_location = True


    print('Have a skateboard (y/n - default=n)?')
    sk = input()
    print('Minimize time (y/n - default=n)?')
    ti = input()



    #t f
    has_skateboard = False
    minimize_time = False
    if sk.lower() == 'y':
        has_skateboard = True
    if ti.lower() == 'y':
        minimize_time = True

    path_list, output = find_path(start_vertex, end_vertex, vertex_data, edge_data, has_skateboard, minimize_time)
    print(output)
    print('Creating the files Route.txt and Routecropped.txt with pixels for the path..')
    create_route_file(path_list,vertex_data)
    print('Done')
    print('Would you like to plot the result from Route.txt into the brandeis map? (Requires the python package PIL to be installed)')
    print('y/n - default n? ')
    plot = input()
    if plot.lower() == 'y':
        plot_on_map()
    
    return


def output_for_samples(vertex_data, edge_data):
    filename = 'sample_output_cases.txt'
    file = open(r"Output.txt","w+") 
    with open(filename) as f:
        for line in f:
            fields = line.split()
            board = fields[3].split('=')[1]
            time = fields[4].split('=')[1]
            if board == 'n':
                has_board = False
            else:
                has_board = True
                
            if time == 'n':
                minimize_time = False
            else:
                minimize_time = True
            start_vertex = get_vertex_id(fields[1],vertex_data)
            end_vertex = get_vertex_id(fields[2],vertex_data)
            path_list, output = find_path(start_vertex, end_vertex, vertex_data, edge_data, has_board, minimize_time)
            
            file.write(line+'\n')
            file.write(output)


            
def tour_outputs_vertex_J(vertex_data, edge_data):
    start_vertex = get_vertex_id('J',vertex_data)
    
    graph_new = construct_graph(vertex_data[5:], edge_data[20:], False, False) #delete the black hole and corners vertices and edges
    min_tree_edges = min_span_tree(graph_new, start_vertex, edge_data[20:])
    file = open(r"OutputP.txt","w+")
    file.write(plotting_cordinates_from_edges(min_tree_edges, edge_data, vertex_data))
    
    krus_edge = kruskal_min_spanning_tree(edge_data[20:], vertex_data[5:], graph_new)
    file = open(r"OutputK.txt","w+")
    file.write(plotting_cordinates_from_edges(krus_edge, edge_data, vertex_data))
    
    file = open(r"OutputPP.txt","w+") 
    file.write(prim_preorder(start_vertex, vertex_data, edge_data))
    
    file = open(r"OutputPS.txt","w+") 
    file.write(prim_shortcut(start_vertex, vertex_data, edge_data))
    
    file = open(r"OutputKP.txt","w+") 
    file.write(kruskal_preorder(start_vertex, vertex_data, edge_data))
    
    return
    

vertex_data = create_vertex_data()
edge_data = create_edge_data()
run_map(vertex_data, edge_data)
output_for_samples(vertex_data, edge_data)
#tour_outputs_vertex_J(vertex_data, edge_data) #used to create the several output files
# Out:
# ******************************WELCOME TO THE BRANDEIS MAP******************************
#
# Entered locations may be:
# the map location(eg L1, U22 etc) or,
# the exact name (farber library etc), or,
# a substring that uniqiely identifies the place (eg., farber l etc)
#
# Enter start (return to quit):
# castle
# Enter finish (or return to do a tour):
#
# Enter one of these tour options:
#     0: Preorder traversal of Prim tree
#     1: Triangle shorcuts of Prim traversal
#     2: Preorder traversal of Kruskal tree
#     or return to quit
# 2
# Would you like to plot the traversal onto the brandeis map? (Requires the python package PIL to be installed)
# y/n - default n?
# n
# FROM: (U40) Usen Castle
# ON: Usen Driveway
# Travel 126 feet in direction 273 degrees West
# TO: (7) Usen Main Entrance
# (28 seconds)
#
# FROM: (7) Usen Main Entrance
# ON: Usen Bypass
# Travel 161 feet in direction 37 degrees NE
# TO: (8) Intersection Of Loop Road And Usen Bypass
# (36 seconds)
#
# FROM: (8) Intersection Of Loop Road And Usen Bypass
# ON: Loop Road
# Travel 257 feet in direction 116 degrees SE
# TO: (9) Loop Road At The Top Of East Quad Steps
# (51 seconds)
#
# FROM: (9) Loop Road At The Top Of East Quad Steps
# ON: East Quad Steps
# Travel 144 feet in direction 88 degrees East
# TO: (U41) Intercultural Center, Swig Hall
# (35 seconds)
#
# FROM: (U41) Intercultural Center, Swig Hall
# ON:
# Travel 109 feet in direction 127 degrees SE
# TO: (U44) Rubenstein-Pomerantz Residence Hall
# (24 seconds)
#
# FROM: (U44) Rubenstein-Pomerantz Residence Hall
# ON:
# Travel 160 feet in direction 23 degrees NE
# TO: (U43) Shapiro Residence Hall
# (35 seconds)
#
# FROM: (U43) Shapiro Residence Hall
# ON:
# Travel 160 feet in direction 203 degrees SW
# TO: (U44) Rubenstein-Pomerantz Residence Hall
# (35 seconds)
#
# FROM: (U44) Rubenstein-Pomerantz Residence Hall
# ON:
# Travel 109 feet in direction 307 degrees NW
# TO: (U41) Intercultural Center, Swig Hall
# (24 seconds)
#
# FROM: (U41) Intercultural Center, Swig Hall
# ON:
# Travel 158 feet in direction 347 degrees North
# TO: (U42) Hassenfeld-Krivoff Residence Hall
# (35 seconds)
#
# FROM: (U42) Hassenfeld-Krivoff Residence Hall
# ON:
# Travel 158 feet in direction 167 degrees South
# TO: (U41) Intercultural Center, Swig Hall
# (35 seconds)
#
# FROM: (U41) Intercultural Center, Swig Hall
# ON: East Quad Steps
# Travel 144 feet in direction 268 degrees West
# TO: (9) Loop Road At The Top Of East Quad Steps
# (64 seconds)
#
# FROM: (9) Loop Road At The Top Of East Quad Steps
# ON: Loop Road
# Travel 257 feet in direction 296 degrees NW
# TO: (8) Intersection Of Loop Road And Usen Bypass
# (63 seconds)
#
# FROM: (8) Intersection Of Loop Road And Usen Bypass
# ON: Loop Road
# Travel 106 feet in direction 334 degrees NW
# TO: (6) Loop Road At The Usdan Student Center West End
# (25 seconds)
#
# FROM: (6) Loop Road At The Usdan Student Center West End
# ON:
# Travel 162 feet in direction 274 degrees West
# TO: (U20) Usdan Student Center
# (36 seconds)
#
# FROM: (U20) Usdan Student Center
# ON:
# Travel 75 feet in direction 328 degrees NW
# TO: (4) Loop Road At The Usdan Student Center
# (17 seconds)
#
# FROM: (4) Loop Road At The Usdan Student Center
# ON: Loop Road
# Travel 197 feet in direction 283 degrees West
# TO: (2) Loop Road By Rabb Steps
# (43 seconds)
#
# FROM: (2) Loop Road By Rabb Steps
# ON: Rabb Steps
# Travel 165 feet in direction 40 degrees NE
# TO: (U14) Rabb Graduate Center
# (72 seconds)
#
# FROM: (U14) Rabb Graduate Center
# ON:
# Travel 149 feet in direction 333 degrees NW
# TO: (0) Mandel Quad
# (33 seconds)
#
# FROM: (0) Mandel Quad
# ON:
# Travel 81 feet in direction 252 degrees West
# TO: (U10) Olin-Sang American Civilization Center
# (18 seconds)
#
# FROM: (U10) Olin-Sang American Civilization Center
# ON:
# Travel 225 feet in direction 269 degrees West
# TO: (U9) Mandel Center for the Humanities
# (50 seconds)
#
# FROM: (U9) Mandel Center for the Humanities
# ON:
# Travel 91 feet in direction 171 degrees South
# TO: (1) Loop Road By Mandel Center
# (18 seconds)
#
# FROM: (1) Loop Road By Mandel Center
# ON: Tower Lot Driveway
# Travel 254 feet in direction 341 degrees North
# TO: ($) Tower Lot
# (62 seconds)
#
# FROM: ($) Tower Lot
# ON:
# Travel 258 feet in direction 199 degrees South
# TO: (U8) Heller School Heller-Brown Building
# (57 seconds)
#
# FROM: (U8) Heller School Heller-Brown Building
# ON:
# Travel 193 feet in direction 281 degrees West
# TO: (U5) Heller School Schneider Building
# (43 seconds)
#
# FROM: (U5) Heller School Schneider Building
# ON:
# Travel 114 feet in direction 11 degrees North
# TO: (U7) Abraham Shapiro Academic Complex
# (25 seconds)
#
# FROM: (U7) Abraham Shapiro Academic Complex
# ON:
# Travel 114 feet in direction 191 degrees South
# TO: (U5) Heller School Schneider Building
# (25 seconds)
#
# FROM: (U5) Heller School Schneider Building
# ON:
# Travel 156 feet in direction 299 degrees NW
# TO: (U6) Mandel Center for Studies in Jewish Education
# (34 seconds)
#
# FROM: (U6) Mandel Center for Studies in Jewish Education
# ON:
# Travel 156 feet in direction 119 degrees SE
# TO: (U5) Heller School Schneider Building
# (34 seconds)
#
# FROM: (U5) Heller School Schneider Building
# ON:
# Travel 193 feet in direction 101 degrees East
# TO: (U8) Heller School Heller-Brown Building
# (43 seconds)
#
# FROM: (U8) Heller School Heller-Brown Building
# ON:
# Travel 258 feet in direction 19 degrees North
# TO: ($) Tower Lot
# (57 seconds)
#
# FROM: ($) Tower Lot
# ON: Tower Lot Driveway
# Travel 254 feet in direction 161 degrees South
# TO: (1) Loop Road By Mandel Center
# (50 seconds)
#
# FROM: (1) Loop Road By Mandel Center
# ON:
# Travel 91 feet in direction 351 degrees North
# TO: (U9) Mandel Center for the Humanities
# (22 seconds)
#
# FROM: (U9) Mandel Center for the Humanities
# ON:
# Travel 225 feet in direction 89 degrees East
# TO: (U10) Olin-Sang American Civilization Center
# (50 seconds)
#
# FROM: (U10) Olin-Sang American Civilization Center
# ON:
# Travel 81 feet in direction 72 degrees East
# TO: (0) Mandel Quad
# (18 seconds)
#
# FROM: (0) Mandel Quad
# ON:
# Travel 118 feet in direction 52 degrees NE
# TO: (U12) Lown School of Near Eastern and Judaic Studies
# (26 seconds)
#
# FROM: (U12) Lown School of Near Eastern and Judaic Studies
# ON:
# Travel 131 feet in direction 148 degrees SE
# TO: (U13) Shiffman Humanities Center
# (29 seconds)
#
# FROM: (U13) Shiffman Humanities Center
# ON:
# Travel 131 feet in direction 328 degrees NW
# TO: (U12) Lown School of Near Eastern and Judaic Studies
# (29 seconds)
#
# FROM: (U12) Lown School of Near Eastern and Judaic Studies
# ON:
# Travel 118 feet in direction 232 degrees SW
# TO: (0) Mandel Quad
# (26 seconds)
#
# FROM: (0) Mandel Quad
# ON:
# Travel 121 feet in direction 308 degrees NW
# TO: (U11) Golding Judaic Center
# (27 seconds)
#
# FROM: (U11) Golding Judaic Center
# ON:
# Travel 121 feet in direction 128 degrees SE
# TO: (0) Mandel Quad
# (27 seconds)
#
# FROM: (0) Mandel Quad
# ON:
# Travel 149 feet in direction 153 degrees SE
# TO: (U14) Rabb Graduate Center
# (33 seconds)
#
# FROM: (U14) Rabb Graduate Center
# ON: Rabb Steps
# Travel 165 feet in direction 220 degrees SW
# TO: (2) Loop Road By Rabb Steps
# (40 seconds)
#
# FROM: (2) Loop Road By Rabb Steps
# ON: Loop Road
# Travel 197 feet in direction 103 degrees East
# TO: (4) Loop Road At The Usdan Student Center
# (43 seconds)
#
# FROM: (4) Loop Road At The Usdan Student Center
# ON:
# Travel 159 feet in direction 83 degrees East
# TO: (:) North Quad Lot
# (35 seconds)
#
# FROM: (:) North Quad Lot
# ON:
# Travel 136 feet in direction 82 degrees East
# TO: (U19) Kutz Hall
# (30 seconds)
#
# FROM: (U19) Kutz Hall
# ON:
# Travel 192 feet in direction 100 degrees East
# TO: (5) Cable Residence Hall Street Entrance
# (42 seconds)
#
# FROM: (5) Cable Residence Hall Street Entrance
# ON: Mandel Rear Access Road
# Travel 162 feet in direction 48 degrees NE
# TO: (U18) Cable Residence Hall
# (36 seconds)
#
# FROM: (U18) Cable Residence Hall
# ON: Mandel Rear Access Road
# Travel 147 feet in direction 340 degrees North
# TO: (U17) Reitman Residence Hall
# (35 seconds)
#
# FROM: (U17) Reitman Residence Hall
# ON: Mandel Rear Access Road
# Travel 147 feet in direction 160 degrees South
# TO: (U18) Cable Residence Hall
# (29 seconds)
#
# FROM: (U18) Cable Residence Hall
# ON: Mandel Rear Access Road
# Travel 162 feet in direction 228 degrees SW
# TO: (5) Cable Residence Hall Street Entrance
# (36 seconds)
#
# FROM: (5) Cable Residence Hall Street Entrance
# ON:
# Travel 167 feet in direction 336 degrees NW
# TO: (3) North Quad
# (37 seconds)
#
# FROM: (3) North Quad
# ON:
# Travel 139 feet in direction 326 degrees NW
# TO: (U16) Gordon Residence Hall
# (31 seconds)
#
# FROM: (U16) Gordon Residence Hall
# ON:
# Travel 181 feet in direction 248 degrees West
# TO: (U15) Scheffres Residence Hall
# (40 seconds)
#
# FROM: (U15) Scheffres Residence Hall
# ON:
# Travel 181 feet in direction 68 degrees East
# TO: (U16) Gordon Residence Hall
# (40 seconds)
#
# FROM: (U16) Gordon Residence Hall
# ON:
# Travel 139 feet in direction 146 degrees SE
# TO: (3) North Quad
# (31 seconds)
#
# FROM: (3) North Quad
# ON:
# Travel 167 feet in direction 156 degrees SE
# TO: (5) Cable Residence Hall Street Entrance
# (37 seconds)
#
# FROM: (5) Cable Residence Hall Street Entrance
# ON:
# Travel 192 feet in direction 280 degrees West
# TO: (U19) Kutz Hall
# (42 seconds)
#
# FROM: (U19) Kutz Hall
# ON:
# Travel 136 feet in direction 262 degrees West
# TO: (:) North Quad Lot
# (30 seconds)
#
# FROM: (:) North Quad Lot
# ON:
# Travel 159 feet in direction 263 degrees West
# TO: (4) Loop Road At The Usdan Student Center
# (35 seconds)
#
# FROM: (4) Loop Road At The Usdan Student Center
# ON:
# Travel 75 feet in direction 148 degrees SE
# TO: (U20) Usdan Student Center
# (17 seconds)
#
# FROM: (U20) Usdan Student Center
# ON:
# Travel 162 feet in direction 94 degrees East
# TO: (6) Loop Road At The Usdan Student Center West End
# (36 seconds)
#
# FROM: (6) Loop Road At The Usdan Student Center West End
# ON: Loop Road
# Travel 106 feet in direction 154 degrees SE
# TO: (8) Intersection Of Loop Road And Usen Bypass
# (20 seconds)
#
# FROM: (8) Intersection Of Loop Road And Usen Bypass
# ON: Usen Bypass
# Travel 161 feet in direction 217 degrees SW
# TO: (7) Usen Main Entrance
# (36 seconds)
#
# FROM: (7) Usen Main Entrance
# ON: Usen Bypass
# Travel 130 feet in direction 157 degrees SE
# TO: (S) Top Of Usen Steps
# (29 seconds)
#
# FROM: (S) Top Of Usen Steps
# ON: Usen Steps
# Travel 184 feet in direction 148 degrees SE
# TO: (=) Science Lot
# (45 seconds)
#
# FROM: (=) Science Lot
# ON:
# Travel 38 feet in direction 136 degrees SE
# TO: (U47) Stoneman Infirmary And Public Safety
# (8 seconds)
#
# FROM: (U47) Stoneman Infirmary And Public Safety
# ON:
# Travel 174 feet in direction 80 degrees East
# TO: (W) Loop Road At The Health Center
# (38 seconds)
#
# FROM: (W) Loop Road At The Health Center
# ON: Health Center Steps
# Travel 213 feet in direction 157 degrees SE
# TO: (X) South St. At The Base Of Health Center Steps
# (52 seconds)
#
# FROM: (X) South St. At The Base Of Health Center Steps
# ON: South Street
# Travel 285 feet in direction 60 degrees NE
# TO: (;) Plant Lot
# (63 seconds)
#
# FROM: (;) Plant Lot
# ON: South Street
# Travel 285 feet in direction 240 degrees SW
# TO: (X) South St. At The Base Of Health Center Steps
# (63 seconds)
#
# FROM: (X) South St. At The Base Of Health Center Steps
# ON:
# Travel 206 feet in direction 104 degrees East
# TO: (A3) Linsey Sports Center And Pool
# (45 seconds)
#
# FROM: (A3) Linsey Sports Center And Pool
# ON:
# Travel 206 feet in direction 132 degrees SE
# TO: (?) Athletic Lower Lot
# (45 seconds)
#
# FROM: (?) Athletic Lower Lot
# ON: Athletics Driveway
# Travel 249 feet in direction 139 degrees SE
# TO: (+) Athletic Back Lot
# (55 seconds)
#
# FROM: (+) Athletic Back Lot
# ON: Athletics Driveway
# Travel 249 feet in direction 319 degrees NW
# TO: (?) Athletic Lower Lot
# (55 seconds)
#
# FROM: (?) Athletic Lower Lot
# ON:
# Travel 251 feet in direction 63 degrees NE
# TO: (A4) Foster Residence Quad
# (55 seconds)
#
# FROM: (A4) Foster Residence Quad
# ON:
# Travel 251 feet in direction 243 degrees SW
# TO: (?) Athletic Lower Lot
# (55 seconds)
#
# FROM: (?) Athletic Lower Lot
# ON:
# Travel 206 feet in direction 312 degrees NW
# TO: (A3) Linsey Sports Center And Pool
# (45 seconds)
#
# FROM: (A3) Linsey Sports Center And Pool
# ON:
# Travel 229 feet in direction 255 degrees West
# TO: (A2) Shapiro Athletic Center
# (51 seconds)
#
# FROM: (A2) Shapiro Athletic Center
# ON:
# Travel 235 feet in direction 138 degrees SE
# TO: (A5) Gosman Sports and Convocation Center
# (52 seconds)
#
# FROM: (A5) Gosman Sports and Convocation Center
# ON:
# Travel 318 feet in direction 205 degrees SW
# TO: (Z) Athletics Driveway Lower Corner
# (70 seconds)
#
# FROM: (Z) Athletics Driveway Lower Corner
# ON:
# Travel 173 feet in direction 100 degrees East
# TO: (A6) Rieger Tennis Courts
# (38 seconds)
#
# FROM: (A6) Rieger Tennis Courts
# ON:
# Travel 173 feet in direction 280 degrees West
# TO: (Z) Athletics Driveway Lower Corner
# (38 seconds)
#
# FROM: (Z) Athletics Driveway Lower Corner
# ON:
# Travel 318 feet in direction 25 degrees NE
# TO: (A5) Gosman Sports and Convocation Center
# (70 seconds)
#
# FROM: (A5) Gosman Sports and Convocation Center
# ON:
# Travel 235 feet in direction 318 degrees NW
# TO: (A2) Shapiro Athletic Center
# (52 seconds)
#
# FROM: (A2) Shapiro Athletic Center
# ON:
# Travel 201 feet in direction 243 degrees SW
# TO: (A2e) Shapiro Athletic Center Entrance
# (44 seconds)
#
# FROM: (A2e) Shapiro Athletic Center Entrance
# ON:
# Travel 113 feet in direction 270 degrees West
# TO: (A1s) Squire Bridge South Entrance
# (25 seconds)
#
# FROM: (A1s) Squire Bridge South Entrance
# ON: Squire Bridge
# Travel 120 feet in direction 328 degrees NW
# TO: (A1) Squire Bridge
# (26 seconds)
#
# FROM: (A1) Squire Bridge
# ON: Squire Bridge
# Travel 167 feet in direction 302 degrees NW
# TO: (A1n) Squire Bridge North Entrance
# (37 seconds)
#
# FROM: (A1n) Squire Bridge North Entrance
# ON: Squire Bridge Steps
# Travel 132 feet in direction 344 degrees North
# TO: (V) Loop Road At The Top Of Squire Bridge Steps
# (58 seconds)
#
# FROM: (V) Loop Road At The Top Of Squire Bridge Steps
# ON:
# Travel 81 feet in direction 289 degrees West
# TO: (U36) Foster Bio-Medical Research Center
# (18 seconds)
#
# FROM: (U36) Foster Bio-Medical Research Center
# ON:
# Travel 157 feet in direction 306 degrees NW
# TO: (U35) Kosow-Wolfson-Rosensweig
# (35 seconds)
#
# FROM: (U35) Kosow-Wolfson-Rosensweig
# ON:
# Travel 134 feet in direction 287 degrees West
# TO: (*) Shapiro Visitor Lot
# (30 seconds)
#
# FROM: (*) Shapiro Visitor Lot
# ON:
# Travel 156 feet in direction 239 degrees SW
# TO: (U34) Rosenstiel Basic Medical Sciences Research Center
# (34 seconds)
#
# FROM: (U34) Rosenstiel Basic Medical Sciences Research Center
# ON:
# Travel 156 feet in direction 59 degrees NE
# TO: (*) Shapiro Visitor Lot
# (34 seconds)
#
# FROM: (*) Shapiro Visitor Lot
# ON:
# Travel 134 feet in direction 107 degrees East
# TO: (U35) Kosow-Wolfson-Rosensweig
# (30 seconds)
#
# FROM: (U35) Kosow-Wolfson-Rosensweig
# ON:
# Travel 157 feet in direction 126 degrees SE
# TO: (U36) Foster Bio-Medical Research Center
# (35 seconds)
#
# FROM: (U36) Foster Bio-Medical Research Center
# ON:
# Travel 81 feet in direction 109 degrees East
# TO: (V) Loop Road At The Top Of Squire Bridge Steps
# (18 seconds)
#
# FROM: (V) Loop Road At The Top Of Squire Bridge Steps
# ON: Squire Bridge Steps
# Travel 132 feet in direction 164 degrees South
# TO: (A1n) Squire Bridge North Entrance
# (32 seconds)
#
# FROM: (A1n) Squire Bridge North Entrance
# ON: Squire Bridge
# Travel 167 feet in direction 122 degrees SE
# TO: (A1) Squire Bridge
# (37 seconds)
#
# FROM: (A1) Squire Bridge
# ON: Squire Bridge
# Travel 120 feet in direction 148 degrees SE
# TO: (A1s) Squire Bridge South Entrance
# (26 seconds)
#
# FROM: (A1s) Squire Bridge South Entrance
# ON:
# Travel 90 feet in direction 197 degrees South
# TO: (Y) Athletics Front Entrance
# (20 seconds)
#
# FROM: (Y) Athletics Front Entrance
# ON: Athletics Driveway
# Travel 187 feet in direction 336 degrees NW
# TO: (A1u) Under Squire Bridge
# (41 seconds)
#
# FROM: (A1u) Under Squire Bridge
# ON: Athletics Driveway
# Travel 187 feet in direction 156 degrees SE
# TO: (Y) Athletics Front Entrance
# (41 seconds)
#
# FROM: (Y) Athletics Front Entrance
# ON: Marcus Field
# Travel 514 feet in direction 218 degrees SW
# TO: (A7) Marcus Field
# (113 seconds)
#
# FROM: (A7) Marcus Field
# ON: Marcus Field
# Travel 418 feet in direction 266 degrees West
# TO: (^) Gordon Bleachers
# (92 seconds)
#
# FROM: (^) Gordon Bleachers
# ON: Gordon Field
# Travel 267 feet in direction 259 degrees West
# TO: (A8) Gordon Field
# (59 seconds)
#
# FROM: (A8) Gordon Field
# ON: Gordon Field
# Travel 267 feet in direction 79 degrees East
# TO: (^) Gordon Bleachers
# (59 seconds)
#
# FROM: (^) Gordon Bleachers
# ON: Athletics Path
# Travel 470 feet in direction 21 degrees North
# TO: (&) Athletic Lot
# (104 seconds)
#
# FROM: (&) Athletic Lot
# ON: Athletics Path
# Travel 470 feet in direction 201 degrees South
# TO: (^) Gordon Bleachers
# (104 seconds)
#
# FROM: (^) Gordon Bleachers
# ON: Marcus Field
# Travel 418 feet in direction 86 degrees East
# TO: (A7) Marcus Field
# (92 seconds)
#
# FROM: (A7) Marcus Field
# ON: Marcus Field
# Travel 514 feet in direction 38 degrees NE
# TO: (Y) Athletics Front Entrance
# (113 seconds)
#
# FROM: (Y) Athletics Front Entrance
# ON:
# Travel 90 feet in direction 17 degrees North
# TO: (A1s) Squire Bridge South Entrance
# (20 seconds)
#
# FROM: (A1s) Squire Bridge South Entrance
# ON:
# Travel 113 feet in direction 90 degrees East
# TO: (A2e) Shapiro Athletic Center Entrance
# (25 seconds)
#
# FROM: (A2e) Shapiro Athletic Center Entrance
# ON:
# Travel 201 feet in direction 63 degrees NE
# TO: (A2) Shapiro Athletic Center
# (44 seconds)
#
# FROM: (A2) Shapiro Athletic Center
# ON:
# Travel 229 feet in direction 75 degrees East
# TO: (A3) Linsey Sports Center And Pool
# (51 seconds)
#
# FROM: (A3) Linsey Sports Center And Pool
# ON:
# Travel 206 feet in direction 284 degrees West
# TO: (X) South St. At The Base Of Health Center Steps
# (45 seconds)
#
# FROM: (X) South St. At The Base Of Health Center Steps
# ON:
# Travel 225 feet in direction 270 degrees West
# TO: (U46) Landsman Research Facility
# (55 seconds)
#
# FROM: (U46) Landsman Research Facility
# ON:
# Travel 202 feet in direction 288 degrees West
# TO: (U48) Mailman House
# (45 seconds)
#
# FROM: (U48) Mailman House
# ON:
# Travel 202 feet in direction 108 degrees East
# TO: (U46) Landsman Research Facility
# (45 seconds)
#
# FROM: (U46) Landsman Research Facility
# ON:
# Travel 130 feet in direction 67 degrees NE
# TO: (U45) Golding Health Center
# (29 seconds)
#
# FROM: (U45) Golding Health Center
# ON:
# Travel 130 feet in direction 247 degrees SW
# TO: (U46) Landsman Research Facility
# (29 seconds)
#
# FROM: (U46) Landsman Research Facility
# ON:
# Travel 225 feet in direction 90 degrees East
# TO: (X) South St. At The Base Of Health Center Steps
# (45 seconds)
#
# FROM: (X) South St. At The Base Of Health Center Steps
# ON: Health Center Steps
# Travel 213 feet in direction 337 degrees NW
# TO: (W) Loop Road At The Health Center
# (94 seconds)
#
# FROM: (W) Loop Road At The Health Center
# ON: East Quad Lower Lot Driveway
# Travel 425 feet in direction 81 degrees East
# TO: (%) East Quad Lower Lot
# (85 seconds)
#
# FROM: (%) East Quad Lower Lot
# ON: East Quad Lower Lot Driveway
# Travel 425 feet in direction 261 degrees West
# TO: (W) Loop Road At The Health Center
# (104 seconds)
#
# FROM: (W) Loop Road At The Health Center
# ON:
# Travel 174 feet in direction 260 degrees West
# TO: (U47) Stoneman Infirmary And Public Safety
# (38 seconds)
#
# FROM: (U47) Stoneman Infirmary And Public Safety
# ON:
# Travel 38 feet in direction 316 degrees NW
# TO: (=) Science Lot
# (8 seconds)
#
# FROM: (=) Science Lot
# ON: Usen Steps
# Travel 184 feet in direction 328 degrees NW
# TO: (S) Top Of Usen Steps
# (82 seconds)
#
# FROM: (S) Top Of Usen Steps
# ON: Usen Bypass
# Travel 130 feet in direction 337 degrees NW
# TO: (7) Usen Main Entrance
# (29 seconds)
#
# FROM: (7) Usen Main Entrance
# ON:
# Travel 63 feet in direction 268 degrees West
# TO: (U39) Lemberg Hall And Children's Center
# (14 seconds)
#
# FROM: (U39) Lemberg Hall And Children's Center
# ON:
# Travel 197 feet in direction 280 degrees West
# TO: (U38) Brown Social Science Center
# (43 seconds)
#
# FROM: (U38) Brown Social Science Center
# ON:
# Travel 187 feet in direction 293 degrees NW
# TO: (U37) Schwartz Hall
# (41 seconds)
#
# FROM: (U37) Schwartz Hall
# ON:
# Travel 112 feet in direction 279 degrees West
# TO: (U) Between Social Sciences And Library
# (25 seconds)
#
# FROM: (U) Between Social Sciences And Library
# ON:
# Travel 160 feet in direction 262 degrees West
# TO: (U23) Pearlman Hall
# (35 seconds)
#
# FROM: (U23) Pearlman Hall
# ON:
# Travel 118 feet in direction 261 degrees West
# TO: (T) Between Sciences and Library
# (26 seconds)
#
# FROM: (T) Between Sciences and Library
# ON:
# Travel 72 feet in direction 189 degrees South
# TO: (U24) Goldsmith Building
# (16 seconds)
#
# FROM: (U24) Goldsmith Building
# ON:
# Travel 157 feet in direction 266 degrees West
# TO: (U25) Volen National Center For Complex Systems
# (35 seconds)
#
# FROM: (U25) Volen National Center For Complex Systems
# ON:
# Travel 140 feet in direction 230 degrees SW
# TO: (U26) Feldberg Communicatins Center
# (31 seconds)
#
# FROM: (U26) Feldberg Communicatins Center
# ON:
# Travel 245 feet in direction 262 degrees West
# TO: (Q) Rosenthal Quad
# (54 seconds)
#
# FROM: (Q) Rosenthal Quad
# ON:
# Travel 105 feet in direction 218 degrees SW
# TO: (L18) Fellows Garden
# (23 seconds)
#
# FROM: (L18) Fellows Garden
# ON:
# Travel 105 feet in direction 38 degrees NE
# TO: (Q) Rosenthal Quad
# (23 seconds)
#
# FROM: (Q) Rosenthal Quad
# ON:
# Travel 140 feet in direction 339 degrees North
# TO: (L15) Rosenthal Residence Hall East
# (31 seconds)
#
# FROM: (L15) Rosenthal Residence Hall East
# ON:
# Travel 122 feet in direction 336 degrees NW
# TO: (L14) Rosenthal Residence Hall North
# (27 seconds)
#
# FROM: (L14) Rosenthal Residence Hall North
# ON:
# Travel 132 feet in direction 352 degrees North
# TO: (U3) Bethlehem Chapel
# (29 seconds)
#
# FROM: (U3) Bethlehem Chapel
# ON:
# Travel 175 feet in direction 287 degrees West
# TO: (U1) Berlin Chapel
# (39 seconds)
#
# FROM: (U1) Berlin Chapel
# ON:
# Travel 75 feet in direction 19 degrees North
# TO: (P) Loop Road At The Chapels
# (17 seconds)
#
# FROM: (P) Loop Road At The Chapels
# ON:
# Travel 130 feet in direction 67 degrees NE
# TO: (U2) Harlan Chapel
# (29 seconds)
#
# FROM: (U2) Harlan Chapel
# ON:
# Travel 130 feet in direction 247 degrees SW
# TO: (P) Loop Road At The Chapels
# (29 seconds)
#
# FROM: (P) Loop Road At The Chapels
# ON:
# Travel 75 feet in direction 199 degrees South
# TO: (U1) Berlin Chapel
# (17 seconds)
#
# FROM: (U1) Berlin Chapel
# ON:
# Travel 175 feet in direction 107 degrees East
# TO: (U3) Bethlehem Chapel
# (39 seconds)
#
# FROM: (U3) Bethlehem Chapel
# ON:
# Travel 132 feet in direction 172 degrees South
# TO: (L14) Rosenthal Residence Hall North
# (29 seconds)
#
# FROM: (L14) Rosenthal Residence Hall North
# ON:
# Travel 122 feet in direction 156 degrees SE
# TO: (L15) Rosenthal Residence Hall East
# (27 seconds)
#
# FROM: (L15) Rosenthal Residence Hall East
# ON:
# Travel 196 feet in direction 55 degrees NE
# TO: (U4) Chapels Field
# (43 seconds)
#
# FROM: (U4) Chapels Field
# ON:
# Travel 196 feet in direction 235 degrees SW
# TO: (L15) Rosenthal Residence Hall East
# (43 seconds)
#
# FROM: (L15) Rosenthal Residence Hall East
# ON:
# Travel 215 feet in direction 241 degrees SW
# TO: (L16) Rosenthal Residence Hall South
# (47 seconds)
#
# FROM: (L16) Rosenthal Residence Hall South
# ON:
# Travel 139 feet in direction 275 degrees West
# TO: (L13) Sherman Hall / Hassenfeld Conference Center
# (31 seconds)
#
# FROM: (L13) Sherman Hall / Hassenfeld Conference Center
# ON:
# Travel 193 feet in direction 354 degrees North
# TO: (L11) Renfield Residence Hall
# (43 seconds)
#
# FROM: (L11) Renfield Residence Hall
# ON:
# Travel 121 feet in direction 94 degrees East
# TO: (L12) Usen Residence Hall
# (27 seconds)
#
# FROM: (L12) Usen Residence Hall
# ON:
# Travel 121 feet in direction 274 degrees West
# TO: (L11) Renfield Residence Hall
# (27 seconds)
#
# FROM: (L11) Renfield Residence Hall
# ON:
# Travel 193 feet in direction 174 degrees South
# TO: (L13) Sherman Hall / Hassenfeld Conference Center
# (43 seconds)
#
# FROM: (L13) Sherman Hall / Hassenfeld Conference Center
# ON:
# Travel 203 feet in direction 185 degrees South
# TO: (L17) Shapiro Campus Center
# (45 seconds)
#
# FROM: (L17) Shapiro Campus Center
# ON:
# Travel 181 feet in direction 134 degrees SE
# TO: (N) Shapiro And Administration Main Entrances
# (40 seconds)
#
# FROM: (N) Shapiro And Administration Main Entrances
# ON:
# Travel 107 feet in direction 212 degrees SW
# TO: (L21) Bernstein-Marcus
# (24 seconds)
#
# FROM: (L21) Bernstein-Marcus
# ON:
# Travel 107 feet in direction 32 degrees NE
# TO: (N) Shapiro And Administration Main Entrances
# (24 seconds)
#
# FROM: (N) Shapiro And Administration Main Entrances
# ON:
# Travel 181 feet in direction 314 degrees NW
# TO: (L17) Shapiro Campus Center
# (40 seconds)
#
# FROM: (L17) Shapiro Campus Center
# ON:
# Travel 164 feet in direction 279 degrees West
# TO: (L8) Faculty Lodge
# (36 seconds)
#
# FROM: (L8) Faculty Lodge
# ON:
# Travel 276 feet in direction 252 degrees West
# TO: (L7) Faculty Center
# (61 seconds)
#
# FROM: (L7) Faculty Center
# ON:
# Travel 181 feet in direction 226 degrees SW
# TO: (I) Loop Road At The Theater
# (40 seconds)
#
# FROM: (I) Loop Road At The Theater
# ON: Loop Road
# Travel 229 feet in direction 118 degrees SE
# TO: (J) Loop Road At The Admissions Building
# (46 seconds)
#
# FROM: (J) Loop Road At The Admissions Building
# ON: Loop Road
# Travel 167 feet in direction 110 degrees East
# TO: (K) Loop Road At The Administration Building
# (41 seconds)
#
# FROM: (K) Loop Road At The Administration Building
# ON:
# Travel 251 feet in direction 118 degrees SE
# TO: (L23) Slosberg Music Center
# (55 seconds)
#
# FROM: (L23) Slosberg Music Center
# ON:
# Travel 208 feet in direction 97 degrees East
# TO: (>) Slodberg Lot
# (46 seconds)
#
# FROM: (>) Slodberg Lot
# ON:
# Travel 208 feet in direction 277 degrees West
# TO: (L23) Slosberg Music Center
# (46 seconds)
#
# FROM: (L23) Slosberg Music Center
# ON:
# Travel 117 feet in direction 263 degrees West
# TO: (<) Admissions Lot
# (26 seconds)
#
# FROM: (<) Admissions Lot
# ON:
# Travel 117 feet in direction 83 degrees East
# TO: (L23) Slosberg Music Center
# (26 seconds)
#
# FROM: (L23) Slosberg Music Center
# ON:
# Travel 251 feet in direction 298 degrees NW
# TO: (K) Loop Road At The Administration Building
# (55 seconds)
#
# FROM: (K) Loop Road At The Administration Building
# ON: Loop Road
# Travel 167 feet in direction 290 degrees West
# TO: (J) Loop Road At The Admissions Building
# (33 seconds)
#
# FROM: (J) Loop Road At The Admissions Building
# ON:
# Travel 140 feet in direction 224 degrees SW
# TO: (L24) Shapiro Admissions Center
# (31 seconds)
#
# FROM: (L24) Shapiro Admissions Center
# ON:
# Travel 175 feet in direction 197 degrees South
# TO: (G) Ridgewood Quad
# (39 seconds)
#
# FROM: (G) Ridgewood Quad
# ON:
# Travel 251 feet in direction 152 degrees SE
# TO: (L28) Village Residence Hall
# (55 seconds)
#
# FROM: (L28) Village Residence Hall
# ON:
# Travel 207 feet in direction 175 degrees South
# TO: (H) West Intersection South St. & Old South St.
# (46 seconds)
#
# FROM: (H) West Intersection South St. & Old South St.
# ON:
# Travel 207 feet in direction 355 degrees North
# TO: (L28) Village Residence Hall
# (46 seconds)
#
# FROM: (L28) Village Residence Hall
# ON:
# Travel 251 feet in direction 332 degrees NW
# TO: (G) Ridgewood Quad
# (55 seconds)
#
# FROM: (G) Ridgewood Quad
# ON:
# Travel 193 feet in direction 271 degrees West
# TO: (L26) Ridgewood Residence Hall B
# (43 seconds)
#
# FROM: (L26) Ridgewood Residence Hall B
# ON:
# Travel 137 feet in direction 242 degrees SW
# TO: (E) Ziv Quad
# (30 seconds)
#
# FROM: (E) Ziv Quad
# ON:
# Travel 162 feet in direction 265 degrees West
# TO: (L30) Ziv Residence Hall A
# (36 seconds)
#
# FROM: (L30) Ziv Residence Hall A
# ON:
# Travel 146 feet in direction 190 degrees South
# TO: (L31) Ziv Residence Hall B
# (32 seconds)
#
# FROM: (L31) Ziv Residence Hall B
# ON:
# Travel 192 feet in direction 119 degrees SE
# TO: (L32) Mazer Residence Hall
# (42 seconds)
#
# FROM: (L32) Mazer Residence Hall
# ON:
# Travel 197 feet in direction 55 degrees NE
# TO: (L29) Ziv Residence Hall D
# (43 seconds)
#
# FROM: (L29) Ziv Residence Hall D
# ON:
# Travel 197 feet in direction 235 degrees SW
# TO: (L32) Mazer Residence Hall
# (43 seconds)
#
# FROM: (L32) Mazer Residence Hall
# ON:
# Travel 249 feet in direction 187 degrees South
# TO: (L33) Epstein Building
# (55 seconds)
#
# FROM: (L33) Epstein Building
# ON: Epstein Driveway
# Travel 273 feet in direction 98 degrees East
# TO: (F) Epstein Entrance
# (60 seconds)
#
# FROM: (F) Epstein Entrance
# ON:
# Travel 162 feet in direction 117 degrees SE
# TO: (@) T-Lot
# (36 seconds)
#
# FROM: (@) T-Lot
# ON:
# Travel 162 feet in direction 297 degrees NW
# TO: (F) Epstein Entrance
# (36 seconds)
#
# FROM: (F) Epstein Entrance
# ON: South Street
# Travel 483 feet in direction 241 degrees SW
# TO: (C) Intersection Turner St. & South St.
# (107 seconds)
#
# FROM: (C) Intersection Turner St. & South St.
# ON: Turner Street
# Travel 364 feet in direction 263 degrees West
# TO: (L35) 567 South Street Apartments
# (80 seconds)
#
# FROM: (L35) 567 South Street Apartments
# ON: South Street
# Travel 414 feet in direction 214 degrees SW
# TO: (L36) May, Lewis, Coffman, and Cohen Residence Halls
# (91 seconds)
#
# FROM: (L36) May, Lewis, Coffman, and Cohen Residence Halls
# ON: South Street
# Travel 414 feet in direction 34 degrees NE
# TO: (L35) 567 South Street Apartments
# (91 seconds)
#
# FROM: (L35) 567 South Street Apartments
# ON: Turner Street
# Travel 364 feet in direction 83 degrees East
# TO: (C) Intersection Turner St. & South St.
# (80 seconds)
#
# FROM: (C) Intersection Turner St. & South St.
# ON:
# Travel 772 feet in direction 281 degrees West
# TO: (L34) 60 Turner Street
# (170 seconds)
#
# FROM: (L34) 60 Turner Street
# ON:
# Travel 772 feet in direction 101 degrees East
# TO: (C) Intersection Turner St. & South St.
# (170 seconds)
#
# FROM: (C) Intersection Turner St. & South St.
# ON: South Street
# Travel 483 feet in direction 61 degrees NE
# TO: (F) Epstein Entrance
# (107 seconds)
#
# FROM: (F) Epstein Entrance
# ON: Epstein Driveway
# Travel 273 feet in direction 278 degrees West
# TO: (L33) Epstein Building
# (60 seconds)
#
# FROM: (L33) Epstein Building
# ON:
# Travel 249 feet in direction 7 degrees North
# TO: (L32) Mazer Residence Hall
# (55 seconds)
#
# FROM: (L32) Mazer Residence Hall
# ON:
# Travel 192 feet in direction 299 degrees NW
# TO: (L31) Ziv Residence Hall B
# (42 seconds)
#
# FROM: (L31) Ziv Residence Hall B
# ON:
# Travel 146 feet in direction 10 degrees North
# TO: (L30) Ziv Residence Hall A
# (32 seconds)
#
# FROM: (L30) Ziv Residence Hall A
# ON:
# Travel 162 feet in direction 85 degrees East
# TO: (E) Ziv Quad
# (36 seconds)
#
# FROM: (E) Ziv Quad
# ON:
# Travel 137 feet in direction 62 degrees NE
# TO: (L26) Ridgewood Residence Hall B
# (30 seconds)
#
# FROM: (L26) Ridgewood Residence Hall B
# ON:
# Travel 288 feet in direction 322 degrees NW
# TO: (L4) Spingold Theater Center
# (64 seconds)
#
# FROM: (L4) Spingold Theater Center
# ON:
# Travel 351 feet in direction 241 degrees SW
# TO: (!) Theater Lot
# (77 seconds)
#
# FROM: (!) Theater Lot
# ON:
# Travel 351 feet in direction 61 degrees NE
# TO: (L4) Spingold Theater Center
# (77 seconds)
#
# FROM: (L4) Spingold Theater Center
# ON:
# Travel 243 feet in direction 273 degrees West
# TO: (D) Between Fine Arts and Theater
# (54 seconds)
#
# FROM: (D) Between Fine Arts and Theater
# ON:
# Travel 240 feet in direction 40 degrees NE
# TO: (L5) Pollack Fine Arts
# (53 seconds)
#
# FROM: (L5) Pollack Fine Arts
# ON:
# Travel 186 feet in direction 29 degrees NE
# TO: (L6) The Rose Art Museum
# (41 seconds)
#
# FROM: (L6) The Rose Art Museum
# ON:
# Travel 186 feet in direction 209 degrees SW
# TO: (L5) Pollack Fine Arts
# (41 seconds)
#
# FROM: (L5) Pollack Fine Arts
# ON:
# Travel 240 feet in direction 220 degrees SW
# TO: (D) Between Fine Arts and Theater
# (53 seconds)
#
# FROM: (D) Between Fine Arts and Theater
# ON:
# Travel 81 feet in direction 353 degrees North
# TO: (L3) Goldman-Schwartz Fine Arts
# (18 seconds)
#
# FROM: (L3) Goldman-Schwartz Fine Arts
# ON:
# Travel 432 feet in direction 270 degrees West
# TO: (L2) IBS - Lemberg Academic Center
# (95 seconds)
#
# FROM: (L2) IBS - Lemberg Academic Center
# ON:
# Travel 287 feet in direction 294 degrees NW
# TO: (L1) IBS - Sachar International Center
# (63 seconds)
#
# FROM: (L1) IBS - Sachar International Center
# ON:
# Travel 287 feet in direction 114 degrees SE
# TO: (L2) IBS - Lemberg Academic Center
# (63 seconds)
#
# FROM: (L2) IBS - Lemberg Academic Center
# ON:
# Travel 171 feet in direction 215 degrees SW
# TO: (A) IBS Lemberg Academic Center Front Entrance
# (38 seconds)
#
# FROM: (A) IBS Lemberg Academic Center Front Entrance
# ON:
# Travel 333 feet in direction 165 degrees South
# TO: (~) Lower Theater Lot
# (73 seconds)
#
# FROM: (~) Lower Theater Lot
# ON: Lower Theater Lot Rear Access
# Travel 296 feet in direction 191 degrees South
# TO: (B) Start Lower Theater Lot Rear Access Road
# (59 seconds)
#
# FROM: (B) Start Lower Theater Lot Rear Access Road
# ON: Lower Theater Lot Rear Access
# Travel 296 feet in direction 11 degrees North
# TO: (~) Lower Theater Lot
# (72 seconds)
#
# FROM: (~) Lower Theater Lot
# ON:
# Travel 333 feet in direction 345 degrees North
# TO: (A) IBS Lemberg Academic Center Front Entrance
# (73 seconds)
#
# FROM: (A) IBS Lemberg Academic Center Front Entrance
# ON:
# Travel 171 feet in direction 35 degrees NE
# TO: (L2) IBS - Lemberg Academic Center
# (38 seconds)
#
# FROM: (L2) IBS - Lemberg Academic Center
# ON:
# Travel 432 feet in direction 90 degrees East
# TO: (L3) Goldman-Schwartz Fine Arts
# (95 seconds)
#
# FROM: (L3) Goldman-Schwartz Fine Arts
# ON:
# Travel 81 feet in direction 173 degrees South
# TO: (D) Between Fine Arts and Theater
# (18 seconds)
#
# FROM: (D) Between Fine Arts and Theater
# ON:
# Travel 243 feet in direction 93 degrees East
# TO: (L4) Spingold Theater Center
# (54 seconds)
#
# FROM: (L4) Spingold Theater Center
# ON:
# Travel 288 feet in direction 142 degrees SE
# TO: (L26) Ridgewood Residence Hall B
# (64 seconds)
#
# FROM: (L26) Ridgewood Residence Hall B
# ON:
# Travel 193 feet in direction 91 degrees East
# TO: (G) Ridgewood Quad
# (43 seconds)
#
# FROM: (G) Ridgewood Quad
# ON:
# Travel 104 feet in direction 85 degrees East
# TO: (L25) Ridgewood Residence Hall A
# (23 seconds)
#
# FROM: (L25) Ridgewood Residence Hall A
# ON:
# Travel 104 feet in direction 265 degrees West
# TO: (G) Ridgewood Quad
# (23 seconds)
#
# FROM: (G) Ridgewood Quad
# ON:
# Travel 114 feet in direction 212 degrees SW
# TO: (L27) Ridgewood Residence Hall C
# (25 seconds)
#
# FROM: (L27) Ridgewood Residence Hall C
# ON:
# Travel 114 feet in direction 32 degrees NE
# TO: (G) Ridgewood Quad
# (25 seconds)
#
# FROM: (G) Ridgewood Quad
# ON:
# Travel 175 feet in direction 17 degrees North
# TO: (L24) Shapiro Admissions Center
# (39 seconds)
#
# FROM: (L24) Shapiro Admissions Center
# ON:
# Travel 140 feet in direction 44 degrees NE
# TO: (J) Loop Road At The Admissions Building
# (31 seconds)
#
# FROM: (J) Loop Road At The Admissions Building
# ON: Loop Road
# Travel 229 feet in direction 298 degrees NW
# TO: (I) Loop Road At The Theater
# (56 seconds)
#
# FROM: (I) Loop Road At The Theater
# ON:
# Travel 181 feet in direction 46 degrees NE
# TO: (L7) Faculty Center
# (40 seconds)
#
# FROM: (L7) Faculty Center
# ON:
# Travel 276 feet in direction 72 degrees East
# TO: (L8) Faculty Lodge
# (61 seconds)
#
# FROM: (L8) Faculty Lodge
# ON:
# Travel 164 feet in direction 99 degrees East
# TO: (L17) Shapiro Campus Center
# (36 seconds)
#
# FROM: (L17) Shapiro Campus Center
# ON:
# Travel 203 feet in direction 5 degrees North
# TO: (L13) Sherman Hall / Hassenfeld Conference Center
# (45 seconds)
#
# FROM: (L13) Sherman Hall / Hassenfeld Conference Center
# ON:
# Travel 231 feet in direction 283 degrees West
# TO: (L9) Shapiro Residence Hal
# (51 seconds)
#
# FROM: (L9) Shapiro Residence Hal
# ON:
# Travel 173 feet in direction 282 degrees West
# TO: (M) Loop Road By The Hassenfeld Lot
# (38 seconds)
#
# FROM: (M) Loop Road By The Hassenfeld Lot
# ON:
# Travel 151 feet in direction 233 degrees SW
# TO: (#) Hassenfeld Lot
# (33 seconds)
#
# FROM: (#) Hassenfeld Lot
# ON:
# Travel 151 feet in direction 53 degrees NE
# TO: (M) Loop Road By The Hassenfeld Lot
# (33 seconds)
#
# FROM: (M) Loop Road By The Hassenfeld Lot
# ON:
# Travel 186 feet in direction 36 degrees NE
# TO: (L10) Deroy Residence Hall
# (41 seconds)
#
# FROM: (L10) Deroy Residence Hall
# ON:
# Travel 186 feet in direction 216 degrees SW
# TO: (M) Loop Road By The Hassenfeld Lot
# (41 seconds)
#
# FROM: (M) Loop Road By The Hassenfeld Lot
# ON:
# Travel 173 feet in direction 102 degrees East
# TO: (L9) Shapiro Residence Hal
# (38 seconds)
#
# FROM: (L9) Shapiro Residence Hal
# ON:
# Travel 231 feet in direction 103 degrees East
# TO: (L13) Sherman Hall / Hassenfeld Conference Center
# (51 seconds)
#
# FROM: (L13) Sherman Hall / Hassenfeld Conference Center
# ON:
# Travel 139 feet in direction 95 degrees East
# TO: (L16) Rosenthal Residence Hall South
# (31 seconds)
#
# FROM: (L16) Rosenthal Residence Hall South
# ON:
# Travel 215 feet in direction 61 degrees NE
# TO: (L15) Rosenthal Residence Hall East
# (47 seconds)
#
# FROM: (L15) Rosenthal Residence Hall East
# ON:
# Travel 140 feet in direction 159 degrees South
# TO: (Q) Rosenthal Quad
# (31 seconds)
#
# FROM: (Q) Rosenthal Quad
# ON: Path Along Top Of Fellows Garden
# Travel 243 feet in direction 154 degrees SE
# TO: (R) Administration Side Entrance
# (54 seconds)
#
# FROM: (R) Administration Side Entrance
# ON:
# Travel 121 feet in direction 270 degrees West
# TO: (L19) Gryzmish Center
# (27 seconds)
#
# FROM: (L19) Gryzmish Center
# ON:
# Travel 148 feet in direction 180 degrees South
# TO: (L20) Irving Presidential Enclave
# (33 seconds)
#
# FROM: (L20) Irving Presidential Enclave
# ON:
# Travel 258 feet in direction 132 degrees SE
# TO: (L22) Main Entrance
# (51 seconds)
#
# FROM: (L22) Main Entrance
# ON:
# Travel 433 feet in direction 68 degrees East
# TO: (O) Loop Road At Below The Science Complex
# (106 seconds)
#
# FROM: (O) Loop Road At Below The Science Complex
# ON:
# Travel 433 feet in direction 248 degrees West
# TO: (L22) Main Entrance
# (87 seconds)
#
# FROM: (L22) Main Entrance
# ON:
# Travel 230 feet in direction 213 degrees SW
# TO: (L) East Intersection South St. & Old South St.
# (51 seconds)
#
# FROM: (L) East Intersection South St. & Old South St.
# ON: Old South Street
# Travel 461 feet in direction 220 degrees SW
# TO: (L40) The Rabb School
# (102 seconds)
#
# FROM: (L40) The Rabb School
# ON: Old South Street
# Travel 461 feet in direction 40 degrees NE
# TO: (L) East Intersection South St. & Old South St.
# (102 seconds)
#
# FROM: (L) East Intersection South St. & Old South St.
# ON:
# Travel 230 feet in direction 33 degrees NE
# TO: (L22) Main Entrance
# (51 seconds)
#
# FROM: (L22) Main Entrance
# ON:
# Travel 258 feet in direction 312 degrees NW
# TO: (L20) Irving Presidential Enclave
# (63 seconds)
#
# FROM: (L20) Irving Presidential Enclave
# ON:
# Travel 148 feet in direction 0 degrees North
# TO: (L19) Gryzmish Center
# (33 seconds)
#
# FROM: (L19) Gryzmish Center
# ON:
# Travel 121 feet in direction 90 degrees East
# TO: (R) Administration Side Entrance
# (27 seconds)
#
# FROM: (R) Administration Side Entrance
# ON: Path Along Top Of Fellows Garden
# Travel 243 feet in direction 334 degrees NW
# TO: (Q) Rosenthal Quad
# (54 seconds)
#
# FROM: (Q) Rosenthal Quad
# ON:
# Travel 245 feet in direction 82 degrees East
# TO: (U26) Feldberg Communicatins Center
# (54 seconds)
#
# FROM: (U26) Feldberg Communicatins Center
# ON:
# Travel 140 feet in direction 50 degrees NE
# TO: (U25) Volen National Center For Complex Systems
# (31 seconds)
#
# FROM: (U25) Volen National Center For Complex Systems
# ON:
# Travel 117 feet in direction 152 degrees SE
# TO: (U27) Abelson-Bass-Yalem
# (26 seconds)
#
# FROM: (U27) Abelson-Bass-Yalem
# ON:
# Travel 90 feet in direction 143 degrees SE
# TO: (U30) Edison-Lecks Science Building
# (20 seconds)
#
# FROM: (U30) Edison-Lecks Science Building
# ON:
# Travel 81 feet in direction 186 degrees South
# TO: (U31) Shapiro Science Center
# (18 seconds)
#
# FROM: (U31) Shapiro Science Center
# ON:
# Travel 81 feet in direction 6 degrees North
# TO: (U30) Edison-Lecks Science Building
# (18 seconds)
#
# FROM: (U30) Edison-Lecks Science Building
# ON:
# Travel 90 feet in direction 323 degrees NW
# TO: (U27) Abelson-Bass-Yalem
# (20 seconds)
#
# FROM: (U27) Abelson-Bass-Yalem
# ON:
# Travel 143 feet in direction 104 degrees East
# TO: (U29) Gerstenzang Science Library
# (32 seconds)
#
# FROM: (U29) Gerstenzang Science Library
# ON:
# Travel 146 feet in direction 56 degrees NE
# TO: (U28) Bassine Science Building
# (32 seconds)
#
# FROM: (U28) Bassine Science Building
# ON:
# Travel 146 feet in direction 236 degrees SW
# TO: (U29) Gerstenzang Science Library
# (32 seconds)
#
# FROM: (U29) Gerstenzang Science Library
# ON:
# Travel 143 feet in direction 284 degrees West
# TO: (U27) Abelson-Bass-Yalem
# (32 seconds)
#
# FROM: (U27) Abelson-Bass-Yalem
# ON:
# Travel 117 feet in direction 332 degrees NW
# TO: (U25) Volen National Center For Complex Systems
# (26 seconds)
#
# FROM: (U25) Volen National Center For Complex Systems
# ON:
# Travel 157 feet in direction 86 degrees East
# TO: (U24) Goldsmith Building
# (35 seconds)
#
# FROM: (U24) Goldsmith Building
# ON:
# Travel 72 feet in direction 9 degrees North
# TO: (T) Between Sciences and Library
# (16 seconds)
#
# FROM: (T) Between Sciences and Library
# ON:
# Travel 132 feet in direction 348 degrees North
# TO: (U22) Farber Library
# (29 seconds)
#
# FROM: (U22) Farber Library
# ON:
# Travel 132 feet in direction 168 degrees South
# TO: (T) Between Sciences and Library
# (29 seconds)
#
# FROM: (T) Between Sciences and Library
# ON:
# Travel 118 feet in direction 81 degrees East
# TO: (U23) Pearlman Hall
# (26 seconds)
#
# FROM: (U23) Pearlman Hall
# ON:
# Travel 160 feet in direction 82 degrees East
# TO: (U) Between Social Sciences And Library
# (35 seconds)
#
# FROM: (U) Between Social Sciences And Library
# ON:
# Travel 169 feet in direction 338 degrees North
# TO: (U21) Goldfarb Library
# (37 seconds)
#
# FROM: (U21) Goldfarb Library
# ON:
# Travel 169 feet in direction 158 degrees South
# TO: (U) Between Social Sciences And Library
# (37 seconds)
#
# FROM: (U) Between Social Sciences And Library
# ON:
# Travel 112 feet in direction 99 degrees East
# TO: (U37) Schwartz Hall
# (25 seconds)
#
# FROM: (U37) Schwartz Hall
# ON:
# Travel 187 feet in direction 113 degrees SE
# TO: (U38) Brown Social Science Center
# (41 seconds)
#
# FROM: (U38) Brown Social Science Center
# ON:
# Travel 197 feet in direction 100 degrees East
# TO: (U39) Lemberg Hall And Children's Center
# (43 seconds)
#
# FROM: (U39) Lemberg Hall And Children's Center
# ON:
# Travel 63 feet in direction 88 degrees East
# TO: (7) Usen Main Entrance
# (14 seconds)
#
# FROM: (7) Usen Main Entrance
# ON: Usen Driveway
# Travel 126 feet in direction 93 degrees East
# TO: (U40) Usen Castle
# (28 seconds)
#
# legs = 292, distance = 57016 feet, time = 12794 seconds
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# ### Scratch Work

# %%
import numpy as np

"""
graph = construct_graph(vertex_data, edge_data, False, False)
min_tree_edges = min_span_tree(graph, 1, edge_data)
plot_edges(min_tree_edges, edge_data, vertex_data)
#this part keeps the edges connecting a map location to the corners, 
#if you want to run this then change the condition while len(T)<num_vertices-1: in the min_span_tree function
#to while len(T)<num_vertices-2:
#this is because the black hole vertex, the one numbered 0, is just an extra vertex connected to nothing
#so the number of edges is going to be not one, but two lesser than the number of total vertices given in the file
"""
#https://www.geeksforgeeks.org/dijkstras-shortest-path-algorithm-greedy-algo-7/

G = { 
0: [(1,4),(7,8)],
1: [(0,4),(2,8),(7,11)],
2: [(1,8), (3,7), (5,4), (8,2)],
3: [(2,7), (4,9), (5,14)],
4: [(3,9), (5,10)],
5: [(2,4), (3,14), (4,10), (6,2)],
6: [(5,2), (7,1), (8,6)],
7: [(0,8), (1,11), (6,1), (8,7)],
8: [(2,2), (6,6), (7,7)]
}

graph = dict()

for key in G:
    l = G[key]
    graph[key] = [(i[0],i[1],i[0]*100+i[1]) for i in l] 
    #graph now has each value of type list of (vertex,cost,edge_id)
start_vertex = 0 
back_pointer = run_Dijkstras(start_vertex,graph)
print_paths(graph, start_vertex, back_pointer)


# check the result of preorder traversal for an example at url
# https://www.hackerearth.com/problem/algorithm/lowest-common-ancestor/
tree = {
    0: [1, 2],
    1: [0,3,4,5],
    2: [6,0],
    3: [1,7],
    4: [1,8,9],
    5: [1],
    6: [2],
    7: [3],
    8: [4],
    9: [4]
    }

for key in tree:
    v = tree[key]
    tree[key] = [(x,-1,np.random.randint(100)) for x in v]

root = 0
traversal = pre_order_trvsl(tree, root, [])
print('ye hai traversal', traversal)
for i in range(len(traversal)-1):
    j = index_in_list(traversal[i+1],tree[traversal[i]])
    print('{} -> {} (edge_id:{} )'.format(traversal[i],traversal[i+1],tree[traversal[i]][j][2]))
    
    
#chekcing the result of Prim's algorithm for the example at the url
#https://www.geeksforgeeks.org/dijkstras-shortest-path-algorithm-greedy-algo-7/
#the answer for the url can be computed by hand

G = { 
0: [(1,4),(7,8)],
1: [(0,4),(2,8),(7,11)],
2: [(1,8), (3,7), (5,4), (8,2)],
3: [(2,7), (4,9), (5,14)],
4: [(3,9), (5,10)],
5: [(2,4), (3,14), (4,10), (6,2)],
6: [(5,2), (7,1), (8,6)],
7: [(0,8), (1,11), (6,1), (8,7)],
8: [(2,2), (6,6), (7,7)]
}

graph = dict()

for key in G:
    l = G[key]
    graph[key] = [(i[0],i[1],i[0]*100+i[1]) for i in l] 
    #graph now has each value of type list of (vertex,cost,edge_id)

edge_data_eg = []

for key in graph:
    for element in graph[key]:
        edge_data_eg.append([element[2],np.random.randint(100),np.random.randint(100),key,element[0],element[1]])
        i+=1

start_vert = 8        
min_tree_edges = min_span_tree(graph, start_vert, edge_data_eg)
min_tree_edges
# Out:
# path from 0 to 0 is given by: [0]
# total cost of this path is: 0
# path from 0 to 1 is given by: [0, 1]
# total cost of this path is: 4
# path from 0 to 2 is given by: [0, 1, 2]
# total cost of this path is: 12
# path from 0 to 3 is given by: [0, 1, 2, 3]
# total cost of this path is: 19
# path from 0 to 4 is given by: [0, 7, 6, 5, 4]
# total cost of this path is: 21
# path from 0 to 5 is given by: [0, 7, 6, 5]
# total cost of this path is: 11
# path from 0 to 6 is given by: [0, 7, 6]
# total cost of this path is: 9
# path from 0 to 7 is given by: [0, 7]
# total cost of this path is: 8
# path from 0 to 8 is given by: [0, 1, 2, 8]
# total cost of this path is: 14
# ye hai traversal [0, 1, 3, 7, 3, 1, 4, 8, 4, 9, 4, 1, 5, 1, 0, 2, 6, 2, 0]
# 0 -> 1 (edge_id:70 )
# 1 -> 3 (edge_id:34 )
# 3 -> 7 (edge_id:99 )
# 7 -> 3 (edge_id:16 )
# 3 -> 1 (edge_id:74 )
# 1 -> 4 (edge_id:32 )
# 4 -> 8 (edge_id:21 )
# 8 -> 4 (edge_id:39 )
# 4 -> 9 (edge_id:7 )
# 9 -> 4 (edge_id:18 )
# 4 -> 1 (edge_id:1 )
# 1 -> 5 (edge_id:25 )
# 5 -> 1 (edge_id:96 )
# 1 -> 0 (edge_id:89 )
# 0 -> 2 (edge_id:88 )
# 2 -> 6 (edge_id:65 )
# 6 -> 2 (edge_id:30 )
# 2 -> 0 (edge_id:86 )
# {104, 202, 204, 207, 309, 602, 701, 708}

# %%
# !jupyter nbconvert --to script COSIProject.ipynb
# Out:
# [NbConvertApp] Converting notebook COSIProject.ipynb to script
# [NbConvertApp] Writing 25186 bytes to COSIProject.py
